# %% [markdown]
# # Render Test Notebook
#
# A minimal pre-executed notebook for testing the `render` subcommand.

# %%
print("hello from render test")
# Out:
# hello from render test

# %%
40 + 2
# Out:
# 42
